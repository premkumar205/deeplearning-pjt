# %% [markdown]
# <a href="https://colab.research.google.com/github/premkumar205/deeplearning-pjt/blob/main/RNN_practices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN,Dense,Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# %%
# sample dataset
data={
    'text':[
        "i love this cinema",
        "this cinema was rampage",
        "amazing acting and story",
        "i hate this cinema",
        "best cinema ever",
        "worst movie ever",
        "Really good cinema",
        "great cinema",
        "not good cinema",
    ],
    'sentiment':[1,0,1,0,1,0,1,1,0]
}

# %%
# convert dictionary into dataframe
df=pd.DataFrame(data)
df
# Out:
#                        text  sentiment
# 0        i love this cinema          1
# 1   this cinema was rampage          0
# 2  amazing acting and story          1
# 3        i hate this cinema          0
# 4          best cinema ever          1
# 5          worst movie ever          0
# 6        Really good cinema          1
# 7              great cinema          1
# 8           not good cinema          0
#                        text  sentiment
# 0        i love this cinema          1
# 1   this cinema was rampage          0
# 2  amazing acting and story          1
# 3        i hate this cinema          0
# 4          best cinema ever          1
# 5          worst movie ever          0
# 6        Really good cinema          1
# 7              great cinema          1
# 8           not good cinema          0

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer=Tokenizer(num_words=1000)
tokenizer.fit_on_texts(df['text'])
sequences=tokenizer.texts_to_sequences(df['text'])

# %%
sequences
# Out:
# [[3, 6, 2, 1],
#  [2, 1, 7, 8],
#  [9, 10, 11, 12],
#  [3, 13, 2, 1],
#  [14, 1, 4],
#  [15, 16, 4],
#  [17, 5, 1],
#  [18, 1],
#  [19, 5, 1]]

# %%
#padding
X=pad_sequences(sequences,maxlen=5)
y=df['sentiment']

# %%
X
# Out:
# array([[ 0,  3,  6,  2,  1],
#        [ 0,  2,  1,  7,  8],
#        [ 0,  9, 10, 11, 12],
#        [ 0,  3, 13,  2,  1],
#        [ 0,  0, 14,  1,  4],
#        [ 0,  0, 15, 16,  4],
#        [ 0,  0, 17,  5,  1],
#        [ 0,  0,  0, 18,  1],
#        [ 0,  0, 19,  5,  1]], dtype=int32)

# %%
#split data into train and test
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
## RNN Model
model=Sequential()

model.add(Embedding(input_dim=1000,output_dim=32,input_length=5))
model.add(SimpleRNN(32))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# compile the model
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
# train model
model.fit(X_train,y_train,epochs=10,batch_size=2)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 261ms/step - accuracy: 0.5714 - loss: 0.6920
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7143 - loss: 0.6583
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7143 - loss: 0.6425
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 0.6205
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8571 - loss: 0.6045
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.5781
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.5515
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.5214
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.4886
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.4504

# %%
loss,accuracy=model.evaluate(X_test,y_test)
print(f"loss:{loss}")
print(f"accuracy:{accuracy}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step - accuracy: 0.0000e+00 - loss: 0.8656
# loss:0.8656349182128906
# accuracy:0.0

# %% [markdown]
# # *Twitter Review on sentiment analysis using RNN:*
#
# - twitter scraping using snscraps

# %%
# !pip install snscrape
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 5.5 MB/s eta 0:00:00
# ...

# %%
df=pd.read_csv('tweets.csv')
df.head()
# Out:
# /tmp/ipykernel_1348/2588502539.py:1: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('tweets.csv')
#               user_name user_location  \
# 0        Auesha Sumayaa           NaN
# 1  Darius Bianchi 🇨🇦 🇮🇹           NaN
# 2       Gabriella Julia           NaN
# 3         𝐈𝐫𝐚𝐧𝐢𝐚𝐧 𝐯𝐨𝐢𝐜𝐞           NaN
# 4         𝐈𝐫𝐚𝐧𝐢𝐚𝐧 𝐯𝐨𝐢𝐜𝐞           NaN
#
#                                     user_description  \
# 0  Passionate #learner and curious observer | #Tw...
# 1  Politics, Historiography, Sociology\n#Resistin...
# 2  #Advocate for #education and promoting inclusi...
# 3  The struggle for freedom and democracy\nhttps:...
# 4  The struggle for freedom and democracy\nhttps:...
#
#                 user_created  user_followers user_friends user_favourites  \
# 0  2020-01-21 05:14:40+00:00          1724.0        548.0            3224
# 1  2020-12-01 17:02:30+00:00          2260.0       1983.0           11789
# ...

# %%
# Uninstall broken version
# !pip uninstall snscrape -y

# Install community-patched version compatible with Python 3.12
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Found existing installation: snscrape 0.7.0.20230622
# Uninstalling snscrape-0.7.0.20230622:
#   Successfully uninstalled snscrape-0.7.0.20230622
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-lgns3exv
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-lgns3exv
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 614d4c2029a62d348ca56598f87c425966aaec66
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for snscrape: filename=snscrape-0.7.0.20230622-py3-none-any.whl size=74851 sha256=c1a381e2d385c5f6981d36eec62344f986d41faf14f013eb6da25edb5120222a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-brpo8_u1/wheels/23/96/eb/f46ee85f779c8e28c7981ded4e8572bfa2bbe2c5bf20ecb4f4
# Successfully built snscrape
# ...

# %%
import tweepy
import pandas as pd
import time

# %%
Bearer_Token="AAAAAAAAAAAAAAAAAAAAADnv8AEAAAAAG1rvIh8DpXEiqqi0uPtpU4aKZ68%3Dtjckaemd5f4ZLyrFuFGp3e8X3PbSKztCbHi2Q9j810eKUgd0sK"

# %%
# calling api key
client =tweepy.Client(bearer_token=Bearer_Token)

# %%
# search query
query="(Iran war OR Iran attack OR Iran missile OR Iran Israel) lang:en -is.retweet -is:reply"

# %%
# collect 1000 tweets in batches of 100
all_tweets=[]
next_token=None
print("Collecting tweets.../n")

while len(all_tweets)<1000:
  Response = client.search_recent_tweets(
      query=query,
      max_results=100,
      tweet_fields=["created_at","author","lang"],
      next_token=next_token
  )
  if Response.data:
    for tweet in Response.data:
      all_tweets.append(
          {
              "id":tweet.id,
              "date":tweet.created_at,
              "text":tweet.text,
              "author":tweet.author_id,
              "like_count":tweet.public_metrics["like_count"],
              "retweet_count":tweet.public_metrics["retweet_count"],
              "replies_count":tweet.public_metrics["reply_count"],

          }
      )
      # if more pages exites
      next_token=Response.meta.get("next_token") if Response.meta None
      if not next_token:
        break
      print(f"Collected {len(all_tweets)} tweets")
      time.sleep(1)
# Out:
#   File "/tmp/ipykernel_1348/3560342665.py", line 28
#     next_token=Response.meta.get("next_token") if Response.meta None
#                ^
# SyntaxError: expected 'else' after 'if' expression
